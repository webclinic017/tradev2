# %%
import pandas as pd
import os
this_dir = os.path.abspath('')
this_dir
# Out:
# '/data/projects/git_repos/tradev2/trade/notebooks'

# %%
df = pd.read_csv(os.path.join(this_dir, '../../output/golden_strat_test_full/full.csv'))
df.head()
# Out:
#             end           p/l    start  sma  fma
# 0  3.451910e+07  2.531910e+07  9200000  101    1
# 1  3.335084e+07  2.415084e+07  9200000  101   11
# 2  3.452035e+07  2.532035e+07  9200000  101   16
# 3  3.320021e+07  2.400021e+07  9200000  101   21
# 4  3.204252e+07  2.284252e+07  9200000  101   26

# %%
df.sort_values(by='p/l', ascending=False)
# Out:
#               end           p/l    start  sma  fma
# 900  4.473350e+08  4.381350e+08  9200000    6    1
# 41   1.206278e+08  1.114278e+08  9200000   11    1
# 253  8.341325e+07  7.421325e+07  9200000   16    1
# 460  6.726735e+07  5.806735e+07  9200000   21    1
# 664  6.010174e+07  5.090174e+07  9200000   26    1
# ..            ...           ...      ...  ...  ...
# 461  1.098319e+07  1.783191e+06  9200000   21   11
# 462  9.339211e+06  1.392108e+05  9200000   21   16
# 255  9.266096e+06  6.609592e+04  9200000   16    6
# 254  7.381798e+06 -1.818202e+06  9200000   16   11
# 42   4.318651e+06 -4.881349e+06  9200000   11    6
#
# [1025 rows x 5 columns]

# %%
newf = df[['sma','fma','p/l']]
newf = newf.pivot(index='sma', columns='fma', values='p/l')
newf
# Out:
# fma           1             6             11            16            21   \
# sma
# 6    4.381350e+08           NaN           NaN           NaN           NaN
# 11   1.114278e+08 -4.881349e+06           NaN           NaN           NaN
# 16   7.421325e+07  6.609592e+04 -1.818202e+06           NaN           NaN
# 21   5.806735e+07  2.536701e+06  1.783191e+06  1.392108e+05           NaN
# 26   5.090174e+07  7.888290e+06  4.103279e+06  2.872171e+06  2.305754e+06
# 31   3.713310e+07  8.202899e+06  4.076964e+06  4.302402e+06  2.794195e+06
# 36   2.632792e+07  5.883439e+06  5.648636e+06  6.797510e+06  6.908607e+06
# 41   2.530650e+07  5.013613e+06  8.138929e+06  9.067118e+06  8.905736e+06
# 46   2.252418e+07  8.664521e+06  1.088642e+07  1.096108e+07  1.148174e+07
# 51   1.995955e+07  1.050435e+07  1.112506e+07  1.435262e+07  1.386888e+07
# 56   2.061025e+07  9.508082e+06  1.308816e+07  1.458207e+07  1.035468e+07
# 61   2.258908e+07  7.927040e+06  1.224853e+07  1.247652e+07  1.234902e+07
# ...

# %%
import numpy as np 
import seaborn as sns
# %matplotlib inline
# sns.set(rc={'axes.facecolor':'pink', 'figure.facecolor':'pink'})
# cmap = sns.diverging_palette(65, 180, s=100, l=80,n=100, center='light',as_cmap=False)
# sns.heatmap(newf, annot=False,cmap=cmap)

# %%
sns.heatmap(newf, annot=False)

# %%
newf = newf[[col for col in newf.columns if col<31]]
sns.heatmap(newf, annot=False,cmap=cmap)
